# %%
import numpy as np

import transpose_invariance as tpi

import skimage as ski

# %%
imgs = tpi.get_3d_images()
img = imgs[0]

# %%
img.shape
# Out:
# (20, 128, 128)

# %%
def func(img):
    return ski.restoration.denoise_nl_means(img)

ws_orig = func(img)

# %%
def check_func(img1, img2):
    assert np.allclose(img1, img2)

# %%
ws_rolled = tpi.rolled_proc(img, (2, 1, 0), func)
check_func(ws_orig, ws_rolled)

# %%
# All images are transpose invariant
tpi.assert_all_orders(imgs, func, chk_func=check_func)
# Out:
# Image 0
# Ordering (0, 2, 1)
# Ordering (1, 2, 0)
# Ordering (2, 1, 0)
# Ordering (2, 0, 1)
# Ordering (1, 0, 2)
# Image 1
# Ordering (0, 2, 1)
# Ordering (1, 2, 0)
# Ordering (2, 1, 0)
# Ordering (2, 0, 1)
# Ordering (1, 0, 2)
# Image 2
# Ordering (0, 2, 1)
# Ordering (1, 2, 0)
